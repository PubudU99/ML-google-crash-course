# %% [markdown]
# <a href="https://colab.research.google.com/github/PubudU99/ML-google-crash-course/blob/main/Pandas_Basic_crash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import pandas as pd
# ##Pandas is the library that used to get the excel type interface

# %%
import numpy as np
import pandas as pd

# %%
my_data = ([1,2],[2,8],[4,7],[2,2],[3,6])

# %%
my_column_names = ['temperature', 'activity']

# %%
df = pd.DataFrame(data = my_data,columns = my_column_names)
df
# Out:
#    temperature  activity
# 0            1         2
# 1            2         8
# 2            4         7
# 3            2         2
# 4            3         6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['temperature'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df["new column"] = df["activity"] + 2
df
# Out:
#    temperature  activity  new column
# 0            1         2           4
# 1            2         8          10
# 2            4         7           9
# 3            2         2           4
# 4            3         6           8

# %% [markdown]
# #For adding columns we sholud attemt by adding numbers to columns in the dataframe.
# We can get access to the columns of the data frame by ***df["Relevent Column Name"]***

# %%
print(df.head(3))     #We can use this to get the first three data in the dataframe
# Out:
#    temperature  activity  new column
# 0            1         2           4
# 1            2         8          10
# 2            4         7           9

# %%
print(df.iloc[[2]])   #for getting the relevent data to the index of the data we can use iloc
# Out:
#    temperature  activity  new column
# 2            4         7           9

# %%
print(df[1:4], '\n')          #By using this we can get the 1 to 4 data in the dataframe

print("Column 'temperature':")
print(df['temperature'])      #This is used to get the data in the relevent column in the dataframe
# Out:
#    temperature  activity  new column
# 1            2         8          10
# 2            4         7           9
# 3            2         2           4
#
# Column 'temperature':
# 0    1
# 1    2
# 2    4
# 3    2
# 4    3
# Name: temperature, dtype: int64
